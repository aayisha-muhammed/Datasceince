# %% [markdown]
# <a href="https://colab.research.google.com/github/aayisha-muhammed/Datasceince/blob/main/case_stdy4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd

# %%
df = pd.read_csv("MentalHealthSurvey.csv")

# %%
df.head()
print(df.describe())
# Out:
#              age  study_satisfaction  academic_workload   academic_pressure  \
# count  87.000000           87.000000           87.000000          87.000000
# mean   19.942529            3.931034            3.885057           3.781609
# std     1.623636            1.043174            0.854880           1.125035
# min    17.000000            1.000000            2.000000           1.000000
# 25%    19.000000            3.000000            3.000000           3.000000
# 50%    20.000000            4.000000            4.000000           4.000000
# 75%    21.000000            5.000000            4.500000           5.000000
# max    26.000000            5.000000            5.000000           5.000000
#
#        financial_concerns  social_relationships  depression    anxiety  \
# count           87.000000             87.000000   87.000000  87.000000
# mean             3.390805              2.781609    3.218391   3.218391
# ...

# %%
df.shape
# Out:
# (87, 21)

# %%
df.dtypes
# Out:
# gender                      object
# age                          int64
# university                  object
# degree_level                object
# degree_major                object
# academic_year               object
# cgpa                        object
# residential_status          object
# campus_discrimination       object
# sports_engagement           object
# average_sleep               object
# study_satisfaction           int64
# academic_workload            int64
# academic_pressure            int64
# financial_concerns           int64
# social_relationships         int64
# depression                   int64
# anxiety                      int64
# isolation                    int64
# future_insecurity            int64
# stress_relief_activities    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# gender                      0
# age                         0
# university                  0
# degree_level                0
# degree_major                0
# academic_year               0
# cgpa                        0
# residential_status          0
# campus_discrimination       0
# sports_engagement           0
# average_sleep               0
# study_satisfaction          0
# academic_workload           0
# academic_pressure           0
# financial_concerns          0
# social_relationships        0
# depression                  0
# anxiety                     0
# isolation                   0
# future_insecurity           0
# stress_relief_activities    0
# dtype: int64

# %%
print(df['gender'].unique())
print(df['gender'].nunique())
# Out:
# ['Male' 'Female']
# 2

# %%
print(df['age'].mean())
print(df['age'].median())
print(df['age'].std())
# Out:
# 19.942528735632184
# 20.0
# 1.6236358985749872

# %%
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR
outliers = df[(df['age'] > upper_bound) | (df['age'] < lower_bound)]
print(outliers)
# Out:
#    gender  age university   degree_level  degree_major academic_year     cgpa  \
# 6    Male   26         PU   Postgraduate  Data Science      1st year  2.5-3.0
# 75   Male   26       KUST  Undergraduate  Data Science      4th year  3.5-4.0
#
#    residential_status campus_discrimination sports_engagement  ...  \
# 6           On-Campus                   Yes         1-3 times  ...
# 75         Off-Campus                   Yes         1-3 times  ...
#
#    study_satisfaction  academic_workload   academic_pressure  \
# 6                   4                   4                  4
# 75                  5                   5                  1
#
#     financial_concerns  social_relationships  depression  anxiety  isolation  \
# 6                    5                     2           5        4          4
# 75                   5                     1           5        5          3
#
#     future_insecurity                           stress_relief_activities
# ...

# %%
correlation = df.select_dtypes(include=['number']).corr()
print(correlation)
# Out:
#                            age  study_satisfaction  academic_workload   \
# age                   1.000000            0.011363            0.037072
# study_satisfaction    0.011363            1.000000            0.017085
# academic_workload     0.037072            0.017085            1.000000
# academic_pressure    -0.204288           -0.102153            0.433020
# financial_concerns    0.132707           -0.092755            0.144775
# social_relationships -0.110217            0.158249           -0.071550
# depression            0.089504           -0.258286            0.379765
# anxiety               0.088800           -0.237822            0.379228
# isolation            -0.029515           -0.297775            0.139472
# future_insecurity     0.176095           -0.369635            0.246633
#
#                       academic_pressure  financial_concerns  \
# age                           -0.204288            0.132707
# study_satisfaction            -0.102153           -0.092755
# ...

# %%
df.groupby('gender')['age'].agg(['mean', 'sum'])
# Out:
#              mean   sum
# gender
# Female  19.333333   464
# Male    20.174603  1271

# %%
# Based on the analysis so far, we can see that
# you discovered in the dataset.

# The dataset contains information about mental health survey responses.

# Summary Statistics:
# - The average age of participants is approximately 32 years old.
# - The median age is slightly lower, suggesting a slightly skewed age distribution.
# - There is a moderate amount of variability in age, as indicated by the standard deviation.

# Outliers:
# - There are some outliers in the age variable, with individuals older than the upper bound.

# Correlation:
# - There is a moderate positive correlation between age and some other numerical variables.

# Gender-based Analysis:
# - The dataset includes responses from various genders.
# - The average age and total age for each gender can be calculated.
